# %% [markdown]
# <a href="https://colab.research.google.com/github/dani-smd/Recommendation-system-for-building-destruction/blob/develop/git_clone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dani-smd/Recommendation-system-for-building-destruction.git
